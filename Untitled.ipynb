# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"E:\project\6 2\Sales_data 1.csv")
df
# Out:
#      Order ID        Date      Customer Name Product Category Product Name  \
# 0           1  04-05-2024      James Mendoza        Furniture     Wardrobe
# 1           2  15-07-2023      Tammy Lambert      Electronics   Smartwatch
# 2           3  25-01-2024  Mckenzie Jennings        Furniture          Bed
# 3           4  17-02-2024     Joshua Johnson         Clothing      Sweater
# 4           5  01-12-2024      Larry Fuentes            Books   Technology
# ..        ...         ...                ...              ...          ...
# 495       496  28-10-2024        Ronald Page        Furniture        Chair
# 496       497  08-08-2024     Benjamin Ramos      Electronics       Laptop
# 497       498  27-12-2024     Kelly Marshall        Furniture     Wardrobe
# 498       499  23-04-2024       Michael Neal         Clothing      Sweater
# 499       500  13-11-2024          David Ray        Furniture        Chair
#
# ...

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df["Total Sales"], bins=20, kde=True, color="blue")

# Customize the plot
plt.title("Distribution of Total Sales")
plt.xlabel("Total Sales")
plt.ylabel("Frequency")
plt.grid(True)

# %%
plt.figure(figsize=(10, 7))
sns.countplot(x=df["Product Category"], palette="viridis")

# Customize the plot
plt.title("Sales Count by Product Category")
plt.xlabel("Product Category")
plt.ylabel("Count")
plt.xticks(rotation=45)  # Rotate labels for better visibility
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show the plot
plt.show()
# Out:
# C:\Users\HI\AppData\Local\Temp\ipykernel_10244\15977789.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df["Product Category"], palette="viridis")

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x=df["Quantity Sold"], y=df["Total Sales"], color="yellow", alpha=0.7)

# Customize the plot
plt.title("Scatter Plot: Quantity Sold vs Total Sales")
plt.xlabel("Quantity Sold")
plt.ylabel("Total Sales")
plt.grid(True)

# Show the plot
plt.show()
